# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    #a=[0]*26
    #b=[0]*26
    a=np.zeros(26)
    b=np.zeros(26)
    for i in range(len(word1)):
        a[ord(word1[i])-97]+=1
    for i in range(len(word1)):
        a[ord(word2[i])-97]+=1
    return a==b

# %%
s1=input('first string')
s2=input('second string')

print(is_anagram(s1,s2))
# Out:
# first stringpost
# second stringtop
# False

# %%
# Out:
# False

# %%
import numpy as np

# %%
is_anagram('tachymetric', 'mccarthyite') # True

# %%
is_anagram('post', 'top') # False, letter not present

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies

# %%
is_anagram('top', 'post') # False, letters left over at the end

# %%
is_anagram('topss', 'postt') # False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 1.79 µs ± 47.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 1.51 µs ± 16.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
def all_anagram_pairs(word_list):
    return []

# %%
all_anagram_pairs(short_word_list)

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')
# Out:
# Downloaded american-english

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
ord('é')
# Out:
# 233

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
# pairs = all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def word_to_key(word):
  a=[0]*27
  b=[0]*27
  for ch in word:
    id=0
    if ord(ch)==39:
      id=26
    elif ord(ch)>122 or ord(ch)<97:
      continue
    else:
      id=ord(ch)-97
    a[id]+=1
  st=''.join(str(aa) for aa in a)
  return st
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.
    
    word_list: sequence of strings
    """
    dic={}
    for word in word_list:
      st=word_to_key(word)

      if st in dic:
        temp=dic[st]
        temp.append(word)
        val=temp
        #val=[*temp, word]
      else:
        val=[word]
      dic.update({st:val})
    return dic

# %%
dic=all_anagram_lists(word_list)

# %%
# %time anagram_map = all_anagram_lists(word_list)

# %%
len(anagram_map)

# %%
print(None)
# Out:
# None

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
def fun():
  temp=dic.items()
  emp={}
  for t in temp:
    if len(t[1])>1:
      emp.update({t[0]:t[1]})
  return emp

part=fun()

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
lis=[*(part.keys())]
a=[*lis[0]]
sm=sum(list(map(int,a)))
ss=sorted(lis,key=lambda st:sum(list(map(int,[*st]))))
(part[ss[len(ss)-1]])
# Out:
# ["impressiveness's", "permissiveness's"]

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
ss2=sorted(lis,key=lambda k: len(part[k]),reverse=True)
part[ss2[0]]
# Out:
# ['teals', 'steal', 'tesla', 'stael', 'stale', 'slate', 'least', 'tales']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
lis=[*part.keys()]
print("length of dictionary=",len(lis))
l=4
sums=[sum(list(map(int,[*st]))) for st in lis]
tp=zip(lis,sums)
ss3=sorted(tp,key=lambda pr:pr[1])
print("SS3=",len(ss3))
ss3n=[val for val in ss3 if val[1]==l]
print("length of sorted list",len(ss3n))
longest=sorted(ss3n, key=lambda item: len(part[item[0]]), reverse=True)
dic2={st:dic[st] for st,sumval in longest}
dic2
# Out:
# length of dictionary= 5916
# SS3= 5916
# length of sorted list 590
# {'100010000001000000100000000': ['lesa',
#   'leas',
#   'elsa',
#   'ales',
#   'seal',
#   'sale'],
#  '000000000000001100110000000': ['tops',
#   'stop',
#   'pots',
#   'post',
#   'opts',
#   'spot'],
#  '000010000000001001100000000': ['roes', 'eros', 'rose', 'sore', 'ores'],
#  '000010000000011000100000000': ['eons', 'nose', 'enos', 'ones', 'noes'],
#  '000000001001001000100000000': ['lois', 'soli', 'oils', 'soil', 'silo'],
#  '100000000000000001110000000': ['tars', 'tsar', 'rats', 'arts', 'star'],
#  '100000000000000100200000000': ['pass', 'spas', 'passé', 'saps', 'asps'],
#  '100010000000000001100000000': ['eras', 'sear', 'ears', 'ares', 'sera'],
#  '100010000000000101000000000': ['pare', 'reap', 'rape', 'earp', 'pear'],
#  '110010000001000000000000000': ['abel', 'able', 'bela', 'elba', 'bale'],
#  '100110000000010000000000000': ['edna', 'aden', 'dane', 'dean', 'dena'],
#  '100010000000000000110000000': ['east', 'sate', 'eats', 'seat', 'teas'],
#  '000010000001011000000000000': ['lone', 'noel', 'leon', 'leno', 'olen'],
#  '000010001001000000000100000': ['live', 'veil', 'evil', 'levi', 'vile'],
#  '100010000001100000000000000': ['lame', 'male', 'meal', 'elam', 'elma'],
#  '100000000000011001000000000': ['arno', 'nora', 'oran', 'roan', 'aron'],
#  '100110000001000000000000000': ['deal', 'leda', 'lead', 'lade', 'dale'],
#  '000000001000010100100000000': ['nips', 'pins', 'spin', 'snip'],
#  '100010000000010000000100000': ['nave', 'vane', 'neva', 'evan'],
#  '110000000001000000100000000': ['albs', 'labs', 'slab', 'blasé'],
#  '010010000000001001000000000': ['robe', 'ebro', 'boer', 'bore'],
#  '100010000000100000010000000': ['mate', 'tame', 'team', 'meat'],
#  '000010000000011100000000000': ['nope', 'open', 'peon', 'pone'],
#  '110000000000000000011000000': ['abut', 'tuba', 'batu', 'tabu'],
#  '000110000000001001000000000': ['oder', 'rode', 'doer', 'redo'],
#  '000011001001000000000000000': ['leif', 'lief', 'life', 'file'],
#  '000010000000010000110000000': ['tens', 'sent', 'nets', 'nest'],
#  '100000000000000101100000000': ['raps', 'rasp', 'pars', 'spar'],
#  '000110000000000000101000000': ['dues', 'used', 'sued', 'duse'],
#  '100010000001000000010000000': ['tale', 'teal', 'leta', 'late'],
#  '100100001000000000100000000': ['aids', 'adiós', 'said', 'dais'],
#  '100000001001000001000000000': ['liar', 'lair', 'rail', 'lira'],
#  '100000000001000000110000000': ['salt', 'last', 'lats', 'slat'],
#  '100010000000110000000000000': ['mane', 'name', 'amen', 'mean'],
#  '100010000000010001000000000': ['earn', 'near', 'rena', 'erna'],
#  '100000000000000100110000000': ['spat', 'pats', 'past', 'taps'],
#  '000010100000001001000000000': ['ogre', 'ergo', 'roeg', 'gore'],
#  '100000000001000100100000000': ['slap', 'alps', 'laps', 'pals'],
#  '100000000000010100100000000': ['snap', 'span', 'naps', 'pans'],
#  '100010000000000001000100000': ['rave', 'vera', 'reva', 'aver'],
#  '000010001000000001010000000': ['teri', 'tire', 'rite', 'tier'],
#  '100010010000000001000000000': ['hare', 'hear', 'rhea', 'hera'],
#  '000010001000000001100000000': ['reis', 'sire', 'rise', 'eris'],
#  '100010000001000100000000000': ['plea', 'pale', 'leap', 'peal'],
#  '101000000000000000110000000': ['cats', 'acts', 'scat', 'cast'],
#  '000010001000100000010000000': ['emit', 'item', 'mite', 'time'],
#  '000110001000000000010000000': ['diet', 'tied', 'edit', 'tide'],
#  '000000100000010000101000000': ['gnus', 'sung', 'guns', 'snug'],
#  '110010000000000000010000000': ['beta', 'bate', 'beat', 'abet'],
#  '000010001000100001000000000': ['mire', 'rime', 'meir', 'emir'],
#  '000010001001010000000000000': ['line', 'nile', 'neil', 'lien'],
#  '100000001000100001000000000': ['amir', 'mari', 'irma', 'mira'],
#  '100110000000100000000000000': ['edam', 'mead', 'dame', 'made'],
#  '000010000001001000100000000': ['leos', 'sloe', 'sole', 'lose'],
#  '000010000000000001101000000': ['user', 'rues', 'sure', 'ruse'],
#  '100010000001000000000100000': ['elva', 'vale', 'vela', 'veal'],
#  '100010000000010000010000000': ['ante', 'etna', 'nate', 'neat'],
#  '110000000000000000110000000': ['bats', 'tabs', 'stab', 'bast'],
#  '100010000001010000000000000': ['neal', 'lane', 'lean', 'lena'],
#  '010000000000000000111000000': ['stub', 'bust', 'tubs', 'buts'],
#  '100000000000000101010000000': ['trap', 'part', 'rapt', 'tarp'],
#  '000000010000000000111000000': ['shut', 'tush', 'thus', 'huts'],
#  '000000001000001001010000000': ['trio', 'riot', 'tiro'],
#  '000020000000000001100000000': ['sere', 'erse', 'seer'],
#  '110010000000000001000000000': ['bear', 'reba', 'bare'],
#  '100010010001000000000000000': ['heal', 'hale', 'leah'],
#  '000010001001000001000000000': ['riel', 'rile', 'lire'],
#  '000110001001000000000000000': ['deli', 'idle', 'lied'],
#  '000000000000011000100010000': ['owns', 'sown', 'snow'],
#  '100000110000000000100000000': ['hags', 'gash', 'shag'],
#  '100010000000000001010000000': ['rate', 'tare', 'tear'],
#  '100000000000100001000000100': ['army', 'myra', 'mary'],
#  '100010000000010000000010000': ['wean', 'wane', 'anew'],
#  '000000000000010000111000000': ['nuts', 'stun', 'tuns'],
#  '100000000000100001100000000': ['mars', 'arms', 'rams'],
#  '000010001001000000100000000': ['isle', 'leis', 'lies'],
#  '000000100000100000101000000': ['gums', 'mugs', 'smug'],
#  '100010000000000000100000100': ['easy', 'ayes', 'yeas'],
#  '000000001000100000200000000': ['sims', 'isms', 'miss'],
#  '100010010000000000010000000': ['hate', 'thea', 'heat'],
#  '000000100000000000111000000': ['gust', 'guts', 'tugs'],
#  '001000001001001000000000000': ['coil', 'clio', 'loci'],
#  '000110000000101000000000000': ['demo', 'mode', 'dome'],
#  '000000001001000100100000000': ['lips', 'slip', 'lisp'],
#  '100000001000010001000000000': ['nair', 'rain', 'iran'],
#  '100010000010000000010000000': ['teak', 'kate', 'take'],
#  '101000000000001000010000000': ['coat', 'taco', 'cato'],
#  '000010000000101000010000000': ['tome', 'moet', 'mote'],
#  '101010000000000001000000000': ['care', 'acre', 'race'],
#  '100010100000000000100000000': ['sage', 'ages', 'sega'],
#  '000010001001100000000000000': ['mile', 'lime', 'emil'],
#  '000110001000000000100000000': ['dies', 'ides', 'side'],
#  '100001000001001000000000000': ['loaf', 'olaf', 'foal'],
#  '000100001010000000100000000': ['disk', 'kids', 'skid'],
#  '200000000001010000000000000': ['lana', 'anal', 'alan'],
#  '100000001001100000000000000': ['lima', 'mail', 'mali'],
#  '000010100001001000000000000': ['loge', 'ogle', 'lego'],
#  '000000010000001100100000000': ['posh', 'hops', 'shop'],
#  '100010000000010100000000000': ['pena', 'nape', 'pane'],
#  '000110001000000001000000000': ['dire', 'reid', 'ride'],
#  '100000010000000000100010000': ['shaw', 'wash', 'haws'],
#  '101010000000100000000000000': ['came', 'acme', 'mace'],
#  '100000000000010001000000100': ['ryan', 'yarn', 'nary'],
#  '000020000001000000100000000': ['lees', 'eels', 'else'],
#  '000010000000011000010000000': ['tone', 'eton', 'note'],
#  '000000001000000100110000000': ['tips', 'spit', 'pits'],
#  '100000000000000100100000100': ['yaps', 'spay', 'pays'],
#  '100010000000000100100000000': ['apse', 'peas', 'apes'],
#  '001000000000001000110000000': ['cots', 'cost', 'scot'],
#  '200000100000000001000000000': ['agar', 'raga', 'agra'],
#  '000000000000100000111000000': ['smut', 'tums', 'must'],
#  '100000010000100000100000000': ['hams', 'sham', 'mash'],
#  '000010000000000000110010000': ['stew', 'wets', 'west'],
#  '000000000001001000100010000': ['slow', 'owls', 'lows'],
#  '000100000000102000000000000': ['odom', 'doom', 'mood'],
#  '000000001010000001100000000': ['kris', 'irks', 'risk'],
#  '000110000000011000000000000': ['node', 'done', 'deon'],
#  '100010000011000000000000000': ['lake', 'kale', 'leak'],
#  '000020000000100000010000000': ['mete', 'meet', 'teem'],
#  '000000001000010000110000000': ['nits', 'snit', 'tins'],
#  '100010000000100001000000000': ['erma', 'mare', 'ream'],
#  '000000001010010000100000000': ['inks', 'skin', 'sink'],
#  '100000001001010000000000000': ['lain', 'lina', 'nail'],
#  '000000000000001001110000000': ['sort', 'rots', 'tors'],
#  '000010000000000000201000000': ['sues', 'suse', 'uses'],
#  '000001000001001000000010000': ['flow', 'fowl', 'wolf'],
#  '100000000000100100100000000': ['spam', 'amps', 'maps'],
#  '000110000000001000100000000': ['odes', 'dose', 'does'],
#  '200000000001000001000000000': ['alar', 'aral', 'lara'],
#  '000010000000010000100010000': ['wens', 'sewn', 'news'],
#  '100011000000000000010000000': ['fate', 'feta', 'feat'],
#  '100000000000010000110000000': ['tans', 'ants', 'stan'],
#  '000000101000000001010000000': ['girt', 'trig', 'grit'],
#  '000000000000001001010000100': ['tory', 'troy', 'tyro'],
#  '100100001001000000000000000': ['dali', 'laid', 'dial'],
#  '000010010000001000100000000': ['hoes', 'shoe', 'hose'],
#  '000000000000001001101000000': ['roués', 'sour', 'ours'],
#  '000000000001001100100000000': ['lops', 'slop', 'pols'],
#  '000000000001001000110000000': ['lost', 'lots', 'slot'],
#  '101000000000000001000000100': ['cary', 'racy', 'cray'],
#  '100000000000111000000000000': ['oman', 'mona', 'moan'],
#  '000000000000001001011000000': ['tour', 'rout', 'outré'],
#  '000010000001001100000000000': ['pole', 'opel', 'lope'],
#  '101000000000000001100000000': ['cars', 'scar', 'arcs'],
#  '100000100001000000100000000': ['gals', 'slag', 'lags'],
#  '100000010010010000000000000': ['ankh', 'khan', 'hank'],
#  '100000000010010001000000000': ['rank', 'nark', 'króna'],
#  '000010000001101000000000000': ['mole', 'elmo', 'lome'],
#  '010000000000010000101000000': ['nubs', 'buns', 'snub'],
#  '100000000000000100100010000': ['wasp', 'paws', 'swap'],
#  '100000001001000000100000000': ['lisa', 'ails', 'sail'],
#  '100000101000010000000000000': ['agni', 'gain', 'gina'],
#  '110110000000000000000000000': ['bead', 'bade', 'abed'],
#  '000020000000000001000010000': ['weer', 'ewer', 'were'],
#  '000000000000001000110010000': ['tows', 'twos', 'stow'],
#  '000010000000000100110000000': ['step', 'pets', 'pest'],
#  '000000100000001001000000100': ['gyro', 'orgy', 'gory'],
#  '000000010000000001011000000': ['ruth', 'thru', 'hurt'],
#  '100000000000100000110000000': ['mats', 'mast', 'tams'],
#  '000000101000010000100000000': ['gins', 'sign', 'sing'],
#  '000110000000010000100000000': ['dens', 'ends', 'send'],
#  '000001001000000000110000000': ['sift', 'fist', 'fits'],
#  '100110000000000001000000000': ['read', 'dear', 'dare'],
#  '000100000000002001000000000': ['door', 'odor', 'rood'],
#  '000100001000011000000000000': ['dino', 'odin', 'dion'],
#  '100000000001100000100000000': ['lams', 'slam', 'alms'],
#  '000010001000000000100100000': ['vise', 'vies', 'ives'],
#  '001000000010001001000000000': ['kroc', 'rock', 'cork'],
#  '000000011000000000110000000': ['this', 'hits', 'shit'],
#  '000110001000000000000100000': ['devi', 'dive', 'vied'],
#  '110100000000000001000000000': ['brad', 'bard', 'drab'],
#  '100000001000010000010000000': ['nita', 'tina', 'anti'],
#  '000020000011000000000000000': ['keel', 'klee', 'leek'],
#  '100010000001000001000000000': ['lear', 'earl', 'real'],
#  '000000000000002000020000000': ['toot', 'otto', 'toto'],
#  '100010000000000000020000000': ['etta', 'tate', 'teat'],
#  '100000001000000000100100000': ['visa', 'siva', 'avis'],
#  '100000100000010000100000000': ['snag', 'sang', 'nags'],
#  '110000100000000001000000000': ['brag', 'grab', 'garb'],
#  '000000001001011000000000000': ['loin', 'lion', 'olin'],
#  '100010000000000100010000000': ['tape', 'pate', 'peat'],
#  '100000000001000000100010000': ['awls', 'slaw', 'laws'],
#  '100000000000000000100010100': ['sway', 'ways', 'yaws'],
#  '000000000001002100000000000': ['polo', 'pool', 'loop'],
#  '100010000000100000100000000': ['mesa', 'seam', 'same'],
#  '100001000000000001010000000': ['frat', 'raft', 'fart'],
#  '000000000000102001000000000': ['moor', 'moro', 'room'],
#  '000000001001000000110000000': ['slit', 'silt', 'list'],
#  '100000000000001001100000000': ['rosa', 'oars', 'soar'],
#  '000000010000001000110000000': ['shot', 'host'],
#  '000000101000000001100000000': ['gris', 'rigs'],
#  '000010000000001000010100000': ['veto', 'vote'],
#  '010000000000000001101000000': ['burs', 'rubs'],
#  '001000000000000100101000000': ['cups', 'cusp'],
#  '001000010000100000001000000': ['chum', 'much'],
#  '000000000100000000111000000': ['just', 'juts'],
#  '000010000000000101000000100': ['pyre', 'prey'],
#  '000000001000011000010000000': ['into', 'toni'],
#  '010010000001000000001000000': ['lube', 'blue'],
#  '100110001000000000000000000': ['idea', 'aide'],
#  '100010000100010000000000000': ['jean', 'jane'],
#  '000000100001000100001000000': ['plug', 'gulp'],
#  '100010000002000000000000000': ['lela', 'ella'],
#  '100100000000100000100000000': ['mads', 'dams'],
#  '100000000000000000110100000': ['vast', 'vats'],
#  '000000000000100100101000000': ['umps', 'sump'],
#  '010100000000001000000000100': ['body', 'boyd'],
#  '000010001000110000000000000': ['mien', 'mine'],
#  '000000001000000000020010000': ['twit', 'witt'],
#  '000010001000000001000010000': ['weir', 'wire'],
#  '000000000000002001010000000': ['oort', 'root'],
#  '000020000001000001000000000': ['reel', 'leer'],
#  '000000001100011000000000000': ['joni', 'join'],
#  '001001001000001000000000000': ['foci', 'coif'],
#  '000010000000010001010000000': ['tern', 'rent'],
#  '000100000000000000111000000': ['dust', 'stud'],
#  '100010100000000100000000000': ['page', 'gape'],
#  '000000101000000000100010000': ['swig', 'wigs'],
#  '000000002010000000000010000': ['kiwi', 'wiki'],
#  '000020000000000001000000100': ['eery', 'eyre'],
#  '200000000100000001000000000': ['ajar', 'raja'],
#  '100010010000000000100000000': ['ashe', 'shea'],
#  '100000100000001000010000000': ['goat', 'toga'],
#  '000000000000011000110000000': ['tons', 'snot'],
#  '100000001001000000010000000': ['tail', 'alit'],
#  '000011000000000000110000000': ['fest', 'fêtes'],
#  '001000000000100000101000000': ['scum', 'cums'],
#  '000000100001001000100000000': ['logs', 'slog'],
#  '101000000000000101000000000': ['carp', 'crap'],
#  '000120000000000001000000000': ['deer', 'reed'],
#  '101000000000100001000000000': ['marc', 'cram'],
#  '000010000000001000100010000': ['owes', 'woes'],
#  '100000000010001001000000000': ['okra', 'karo'],
#  '100100000000001001000000000': ['dora', 'road'],
#  '000000111000000000100000000': ['sigh', 'gish'],
#  '000011000001000000001000000': ['flue', 'fuel'],
#  '000020000001000100000000000': ['peel', 'pele'],
#  '100001000000000000110000000': ['fats', 'fast'],
#  '000000001000010000100000001': ["ni's", "in's"],
#  '100000000000011000000100000': ['avon', 'nova'],
#  '100000001000000001000000100': ['airy', 'iyar'],
#  '000000011000000000010010000': ['with', 'whit'],
#  '000010001010000001000000000': ['keri', 'erik'],
#  '000110000000001000010000000': ['toed', 'dote'],
#  '110000000011000000000000000': ['balk', 'kalb'],
#  '000010010000010000000010000': ['hewn', 'when'],
#  '100110000000000000000100000': ['dave', 'veda'],
#  '000000001010000000200000000': ['skis', 'kiss'],
#  '000000010000001000100000001': ["oh's", "ho's"],
#  '100000000000100000100000100': ['yams', 'mays'],
#  '100000001000100000100000000': ['aims', 'siam'],
#  '000000000000001000200000001': ["so's", "os's"],
#  '100100010000000000100000000': ['shad', 'dash'],
#  '000010010000000000200000000': ['hess', 'shes'],
#  '000010000000001001000010000': ['wore', 'rowe'],
#  '010000000000001000200000000': ['sobs', 'boss'],
#  '101010000000000100000000000': ['cape', 'pace'],
#  '100100000000000001000010000': ['draw', 'ward'],
#  '100000000000000001010000100': ['arty', 'tray'],
#  '010010001000000001000000000': ['brie', 'bier'],
#  '000010000001000001001000000': ['rule', 'lure'],
#  '100210000000000000000000000': ['edda', 'dead'],
#  '000000010010010000001000000': ['hunk', 'kuhn'],
#  '120000000000000000000000100': ['baby', 'abby'],
#  '100000000011000001000000000': ['lark', 'karl'],
#  '010000100000001000100000000': ['gobs', 'bogs'],
#  '000010000000111000000000000': ['omen', 'nome'],
#  '001100000000000001001000000': ['curd', 'crud'],
#  '000100010000001000100000000': ['hods', 'shod'],
#  '100110000000000000000010000': ['awed', 'wade'],
#  '100000000001001000100000000': ['laos', 'also'],
#  '100110000000000000000000010': ['adze', 'daze'],
#  '110000001001000000000000000': ['bali', 'bail'],
#  '110000000000010001000000000': ['bran', 'barn'],
#  '100010100000000001000000000': ['rage', 'gear'],
#  '011010000000000000001000000': ['cebu', 'cube'],
#  '100011000001000000000000000': ['flea', 'leaf'],
#  '000021000001000000000000000': ['feel', 'flee'],
#  '001000000001002000000000000': ['loco', 'cool'],
#  '000000000001100100001000000': ['lump', 'plum'],
#  '000000110000000000101000000': ['gush', 'hugs'],
#  '000020000010000000100000000': ['seek', 'ekes'],
#  '101000001000010000000000000': ['cain', 'inca'],
#  '100000100000010000000000100': ['yang', 'nagy'],
#  '100000000000110000000000100': ['myna', 'many'],
#  '000020000010010000000000000': ['keen', 'knee'],
#  '100000000001000000100000100': ['slay', 'lays'],
#  '100000010000000100010000000': ['ptah', 'path'],
#  '000020010000000001000000000': ['rhee', 'here'],
#  '101010000001000000000000000': ['alec', 'lace'],
#  '000110000000010001000000000': ['rend', 'nerd'],
#  '100000100000000001000000100': ['gary', 'gray'],
#  '100000010000000000010010000': ['thaw', 'what'],
#  '100000100000001000000000100': ['yoga', 'goya'],
#  '100000000000010000011000000': ['tuna', 'aunt'],
#  '101000000000010000100000000': ['scan', 'cans'],
#  '001000001000011000000000000': ['icon', 'coin'],
#  '000000000010001001000000100': ['york', 'kory'],
#  '100100001000000000000100000': ['avid', 'diva'],
#  '100200000000000000100000000': ['adds', 'dads'],
#  '101000000001000000000000100': ['lacy', 'clay'],
#  '000010000000101000100000000': ['emos', 'some'],
#  '000010000000000101001000000': ['pure', 'peru'],
#  '001110000000001000000000000': ['code', 'coed'],
#  '100000000000100000100010000': ['maws', 'swam'],
#  '101000000000000000020000000': ['tact', 'catt'],
#  '100000010000000000100000100': ['hays', 'ashy'],
#  '000010001000000101000000000': ['pier', 'ripe'],
#  '000010000000021000000000000': ['neon', 'none'],
#  '000000001010000000110000000': ['kits', 'skit'],
#  '100000000000100000100000001': ["ma's", "am's"],
#  '100010100001000000000000000': ['gale', 'gael'],
#  '101000000001000000010000000': ['talc', 'éclat'],
#  '100000000000010000100010000': ['sawn', 'swan'],
#  '100100000001000000001000000': ['laud', 'dual'],
#  '100000010000000000110000000': ['shat', 'hats'],
#  '000110000000000000011000000': ['étude', 'duet'],
#  '100010000001000000001000000': ['eula', 'laue'],
#  '000100000000001101000000000': ['prod', 'drop'],
#  '100010000000010000100000000': ['sean', 'sane'],
#  '000021000000000001000000000': ['reef', 'free'],
#  '100010000001000000000010000': ['wale', 'weal'],
#  '000100101000000001000000000': ['gird', 'grid'],
#  '100100000000000001000000100': ['yard', 'dray'],
#  '000110011000000000000000000': ['hide', 'hied'],
#  '010000001000010000100000000': ['nibs', 'bins'],
#  '100100000000010001000000000': ['rand', 'darn'],
#  '100010000000000002000000000': ['rare', 'rear'],
#  '101010010000000000000000000': ['ache', 'each'],
#  '000010000001100000100000000': ['elms', 'mêlées'],
#  '000010000000000100100010000': ['spew', 'pews'],
#  '000010000000001001000100000': ['over', 'rove'],
#  '000010000000001100100000000': ['pose', 'peso'],
#  '100000000001010000001000000': ['ulna', 'luna'],
#  '000010000001001000000100000': ['vole', 'love'],
#  '100010000001000000000001000': ['alex', 'axle'],
#  '000010000001001001000000000': ['lore', 'role'],
#  '200000000001000000000100000': ['lava', 'alva'],
#  '001100000000001000100000000': ['docs', 'cods'],
#  '000010001011000000000000000': ['kiel', 'like'],
#  '000100001000001000000100000': ['void', 'ovid'],
#  '000001100001001000000000000': ['flog', 'golf'],
#  '110000000000000001100000000': ['bars', 'bras'],
#  '110000000001100000000000000': ['balm', 'lamb'],
#  '000000000000100000201000000': ['muss', 'sums'],
#  '000011000000000001100000000': ['refs', 'serf'],
#  '100100001000000100000000000': ['ipad', 'paid'],
#  '010100000000000000101000000': ['buds', 'dubs'],
#  '000000000001002000010000000': ['tool', 'loot'],
#  '100000000001001100000000000': ['alpo', 'opal'],
#  '000010000000000000101000010': ['zeus', 'suez'],
#  '010000000000000000101000100': ['busy', 'buys'],
#  '100000000010001000100000000': ['oaks', 'soak'],
#  '100000100000000100100000000': ['gaps', 'gasp'],
#  '000120100000000000000000000': ['edge', 'geed'],
#  '000000000000001001020000000': ['trot', 'tort'],
#  '101100000000000000100000000': ['scad', 'cads'],
#  '100000000001100100000000000': ['palm', 'lamp'],
#  '100000000000100001010000000': ['tram', 'mart'],
#  '210000000000000000100000000': ['baas', 'saab'],
#  '000010000000100000101000000': ['emus', 'muse'],
#  '100100001000100000000000000': ['maid', 'amid'],
#  '000000001001101000000000000': ['limo', 'milo'],
#  '100000001000110000000000000': ['mani', 'main'],
#  '111000000000000000100000000': ['cabs', 'scab'],
#  '000000010000010000101000000': ['huns', 'shun'],
#  '000000100001000000101000000': ['lugs', 'slug'],
#  '110000100000000000100000000': ['bags', 'gabs'],
#  '100000100000010000000010000': ['wang', 'gnaw'],
#  '200000000000100001000000000': ['rama', 'mara'],
#  '000000000000011000100000100': ['nosy', 'sony'],
#  '100100000000010000000010000': ['dawn', 'wand'],
#  '000010011000000001000000000': ['heir', 'hire'],
#  '100000000010000000200000000': ['asks', 'saks'],
#  '010000000000011001000000000': ['born', 'brno'],
#  '000000001002000000010000000': ['till', 'lilt'],
#  '010010000000000001010000000': ['bret', 'bert'],
#  '000000010000001001010000000': ['thor', 'roth'],
#  '000010000000010000010010000': ['went', 'newt'],
#  '100010000000000001000010000': ['ware', 'wear'],
#  '100000001000000001100000000': ['sari', 'airs'],
#  '000000001000011001000000000': ['orin', 'iron'],
#  '000000000000001101010000000': ['pôrto', 'port'],
#  '101000010000000100000000000': ['chap', 'caph'],
#  '100000100000000000110000000': ['tags', 'stag'],
#  '101000010000000001000000000': ['arch', 'char'],
#  '100001000000001001000000000': ['afro', 'fora'],
#  '001010001000000001000000000': ['rice', 'eric'],
#  '101000000000100000100000000': ['scam', 'cams'],
#  '010110000000000000100000000': ['debs', 'beds'],
#  '100000100000000000100010000': ['wags', 'swag'],
#  '000000101000100001000000000': ['émigré', 'grim'],
#  '000000001010011000000000000': ['ikon', 'oink'],
#  '110000000000010000100000000': ['nabs', 'bans'],
#  '100100001000000001000000000': ['arid', 'raid'],
#  '000000000000001000120000000': ['tost', 'tots'],
#  '000000000000001000111000000': ['oust', 'outs'],
#  '000010001000010001000000000': ['rein', 'erin'],
#  '000000001011010000000000000': ['kiln', 'link'],
#  '000000000000101000110000000': ['toms', 'most'],
#  '000110001000010000000000000': ['dine', 'enid'],
#  '100001000000001000100000000': ['sofa', 'oafs'],
#  '000010001000000000110000000': ['site', 'ties'],
#  '101000000001100000000000000': ['clam', 'calm'],
#  '000000000000001000210000000': ['sots', 'toss'],
#  '000000000000010001101000000': ['urns', 'runs'],
#  '000010001010000000010000000': ['kite', 'tike'],
#  '000000000000000001111000000': ['rust', 'ruts'],
#  '000000010000002000100000000': ['shoo', 'soho'],
#  '000000000000001100101000000': ['soup', 'opus'],
#  '000010000000001001010000000': ['tore', 'rote'],
#  '000000000000000100201000000': ['sups', 'puss'],
#  '100000101001000000000000000': ['gila', 'gail'],
#  '000010000000000000100001001': ["xe's", "ex's"],
#  '010000000000000100100000001': ["bp's", "pb's"],
#  '100000000011010000000000000': ['lank', 'klan'],
#  '200000100001000000000000000': ['alga', 'gala'],
#  '000000000000111001000000000': ['norm', 'morn'],
#  '000000011000100000100000000': ['hims', 'shim'],
#  '000000010001001000010000000': ['loth', 'holt'],
#  '000010000000011000000000010': ['zeno', 'zone'],
#  '100000000000000200100000000': ['paps', 'apps'],
#  '010000010000001000100000000': ['hobs', 'bosh'],
#  '000001001001000000010000000': ['flit', 'lift'],
#  '000100001001000000000000100': ['idyl', 'idly'],
#  '000010000000000100100000100': ['espy', 'yeps'],
#  '000000010000001000100010000': ['hows', 'show'],
#  '000010000001000100000000100': ['yelp', 'pyle'],
#  '000011000001000000010000000': ['left', 'felt'],
#  '100100100000000001000000000': ['drag', 'grad'],
#  '000000000000010001011000000': ['turn', 'runt'],
#  '000110000001000000000010000': ['lewd', 'weld'],
#  '100000001000200000000000000': ['maim', 'imam'],
#  '000010001001000000010000000': ['tile', 'lite'],
#  '000000000000101101000000000': ['romp', 'prom'],
#  '000020001000000001000000000': ['erie', 'eire'],
#  '010010000000000000110000000': ['bets', 'best'],
#  '000110000001001000000000000': ['dole', 'lode'],
#  '000000001000000000110000001': ["ti's", "it's"],
#  '000020000000000001000100000': ['veer', 'ever'],
#  '000000000001011000000000100': ['lyon', 'only'],
#  '000100001001000000100000000': ['lids', 'slid'],
#  '001100000000000000101000000': ['cuds', 'scud'],
#  '010000000000000001011000000': ['brut', 'burt'],
#  '000000001001001001000000000': ['lori', 'roil'],
#  '000010100001000000100000000': ['legs', 'gels'],
#  '100000001001000000000100000': ['vial', 'vila'],
#  '000000001011000000100000000': ['ilks', 'silk'],
#  '100010000000000100000100000': ['pave', 'vape'],
#  '000012001000000000000000000': ['fife', 'fief'],
#  '100100000001001000000000000': ['load', 'aldo'],
#  '000011001000000001000000000': ['rife', 'fire'],
#  '000010001000000000000110000': ['wive', 'view'],
#  '000000000000011000010010000': ['wont', 'town'],
#  '100111000000000000000000000': ['fade', 'deaf'],
#  '000010000000101100000000000': ['poem', 'mope'],
#  '000010000000011001000000000': ['nero', 'reno'],
#  '101010000000010000000000000': ['cane', 'acne'],
#  '100000000000000001000010100': ['awry', 'wary'],
#  '001000000001001000010000000': ['colt', 'clot'],
#  '200000000001100000000000000': ['lama', 'alma'],
#  '010000100001001000000000000': ['blog', 'glob'],
#  '000001000000101001000000000': ['from', 'form'],
#  '001010000000011000000000000': ['once', 'cone'],
#  '000011001000010000000000000': ['fine', 'enif'],
#  '001000011000010000000000000': ['chin', 'inch'],
#  '100000000000021000000000000': ['anon', 'nona'],
#  '110010000000010000000000000': ['bane', 'bean'],
#  '000010000001000001000000100': ['rely', 'lyre'],
#  '010010000001001000000000000': ['lobe', 'bole'],
#  '000020000000000000100010000': ['wees', 'ewes'],
#  '210000000001000000000000000': ['baal', 'alba'],
#  '000000100000000001101000000': ['rugs', 'grus'],
#  '001010000000000001001000000': ['ecru', 'cure'],
#  '000100100000001000100000000': ['gods', 'dogs'],
#  '000100001000000000100000001': ["di's", "id's"],
#  '000010000002000000100000000': ['ells', 'sell'],
#  '000010000000000000110100000': ['vest', 'vets'],
#  '100000010000010000100000000': ['hans', 'nash'],
#  '000010000100000000110000000': ['jets', 'jest'],
#  '000000001001100000100000000': ['mils', 'slim'],
#  '010000000000001001100000000': ['robs', 'orbs'],
#  '100000000001011000000000000': ['nola', 'loan'],
#  '100010100000000000000100000': ['gave', 'vega'],
#  '100011000000000001000000000': ['fare', 'fear'],
#  '100010000000000001000000010': ['ezra', 'raze'],
#  '001010000001001000000000000': ['cole', 'cleo'],
#  '010000000000000001001000100': ['ruby', 'bury'],
#  '010000000001001000010000000': ['blot', 'bolt'],
#  '001010000001000000001000000': ['clue', 'luce'],
#  '000001000000000001101000000': ['furs', 'surf'],
#  '100000010001000000001000000': ['haul', 'hula'],
#  '000120000000010000000000000': ['eden', 'need'],
#  '001010000000000100100000000': ['pecs', 'spec'],
#  '001000010000001000001000000': ['ouch', 'chou'],
#  '000010000000000000210000000': ['tess', 'sets'],
#  '000000000010000001011000000': ['turk', 'kurt'],
#  '000120000000000100000000000': ['peed', 'deep'],
#  '100000100001001000000000000': ['olga', 'goal'],
#  '100000000001001001000000000': ['oral', 'lora'],
#  '000010000000001101000000000': ['pore', 'rope'],
#  '000110000000010000001000000': ['nude', 'dune'],
#  '200100000000010000000000000': ['dana', 'adan'],
#  '000000001000000100200000000': ['sips', 'piss'],
#  '000010000001000100010000000': ['lept', 'pelt'],
#  '010000000001001000000010000': ['blow', 'bowl'],
#  '000000000000002000110000000': ['soot', 'soto'],
#  '100000000000010001010000000': ['tran', 'rant'],
#  '000000001000100000110000000': ['smit', 'mist'],
#  '000000010000100000101000000': ['hums', 'mush'],
#  '010000000000012000000000000': ['bono', 'boon'],
#  '101000000001001000000000000': ['cola', 'coal'],
#  '010000010000000000101000000': ['hubs', 'bush'],
#  '010000100000000001001000000': ['grub', 'burg'],
#  '000010001000010000100000000': ['sine', 'ines'],
#  '000010000002000000000000100': ['lyle', 'yell'],
#  '010000000001000001001000000': ['burl', 'blur'],
#  '000001001001100000000000000': ['milf', 'film'],
#  '000210000000000000000000100': ['dyed', 'eddy'],
#  '100000000001000001001000000': ['raul', 'ural'],
#  '000000011000010000010000000': ['thin', 'hint'],
#  '000010000000000000110000100': ['yest', 'stye'],
#  '100000010000000001010000000': ['hart', 'thar'],
#  '000020000000000100100000000': ['seep', 'pees'],
#  '100000010001000000100000000': ['lash', 'hals'],
#  '101000000010000000100000000': ['cask', 'sack'],
#  '000110000000000001001000000': ['rude', 'rued'],
#  '001000000000001000100010000': ['scow', 'cows'],
#  '001000011000000000010000000': ['itch', 'chit'],
#  '000000000001002000100000000': ['solo', 'oslo'],
#  '100010000001000000000000010': ['zeal', 'laze'],
#  '000110001000100000000000000': ['diem', 'dime'],
#  '110100000000000000001000000': ['daub', 'baud'],
#  '100000001000010000000100000': ['vain', 'ivan'],
#  '101000000011000000000000000': ['lack', 'calk'],
#  '200000000000000001100000000': ['saar', 'sara'],
#  '000000100000002100000000000': ['pogo', 'goop'],
#  '000000010000002100000000000': ['pooh', 'hoop'],
#  '001100000001001000000000000': ['clod', 'cold'],
#  '100010000010000000000010000': ['wake', 'weak'],
#  '000000101000000101000000000': ['grip', 'prig'],
#  '100000100000010000010000000': ['gnat', 'tang'],
#  '000010001000010000000100000': ['vein', 'vine'],
#  '100000000001001000000100000': ['oval', 'olav'],
#  '000010001000010000010000000': ['tine', 'nite'],
#  '000000001000000000110010000': ['wist', 'wits'],
#  '101000000000000000100000001': ["ca's", "ac's"],
#  '010000000000000000201000000': ['buss', 'subs'],
#  '000100000001001000010000000': ['dolt', 'told'],
#  '100000020000000000100000000': ['shah', 'hash'],
#  '001000010010001000000000000': ['koch', 'hock'],
#  '110010000010000000000000000': ['beak', 'bake'],
#  '000010010000100000100000000': ['mesh', 'hems'],
#  '100000010001000000010000000': ['halt', 'lath'],
#  '000000000001000000111000000': ['lust', 'slut'],
#  '000000001002000000100000000': ['sill', 'ills'],
#  '000000011000000100100000000': ['hips', 'ship'],
#  '100000000000000101000010000': ['warp', 'wrap'],
#  '000010000010000000100000100': ['skye', 'keys'],
#  '100000000000101001000000000': ['omar', 'roam'],
#  '100000000001100000001000000': ['maul', 'alum'],
#  '100010000000000000100100000': ['vase', 'save'],
#  '100000000000100101000000000': ['pram', 'ramp'],
#  '000010100000001000100000000': ['egos', 'goes'],
#  '000110100001000000000000000': ['geld', 'gödel'],
#  '000000101000010001000000000': ['grin', 'ring'],
#  '000110000000010000010000000': ['tend', 'dent'],
#  '000010000000000001010000100': ['tyre', 'trey'],
#  '000000000001001000200000000': ['loss', 'sols'],
#  '000000000000011000101000000': ['onus', 'nous'],
#  '000000001011001000000000000': ['loki', 'kilo'],
#  '000000000000112000000000000': ['mono', 'moon'],
#  '000011000000000001000000100': ['frey', 'frye'],
#  '000010000001000000110000000': ['lets', 'lest'],
#  '100010000000000001000000100': ['aery', 'year'],
#  '001110001000000000000000000': ['dice', 'iced'],
#  '000000110000001000100000000': ['hogs', 'gosh'],
#  '000010000000101001000000000': ['more', 'rome'],
#  '000100000000011000100000000': ['nods', 'dons'],
#  '000011000000010001000000000': ['fern', 'nerf'],
#  '101010000000000000100000000': ['aces', 'case'],
#  '100000000000101000010000000': ['atom', 'moat'],
#  '000000000000010100101000000': ['puns', 'spun'],
#  '100000000001000000100000001': ["la's", "al's"],
#  '100000000010010000010000000': ['kant', 'tank'],
#  '000020000010000100000000000': ['keep', 'peek'],
#  '000000100000011000000010000': ['wong', 'gown'],
#  '010000000001001000100000000': ['slob', 'lobs'],
#  '010020000000010000000000000': ['eben', 'been'],
#  '000010100000100000100000000': ['gems', 'megs']}

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
part
temp=[]
for k,v in part.items():
  temp=[*temp, v]
temp
# Out:
# [['mauro', 'amour'],
#  ['hob', 'hbo'],
#  ['reserves', 'reverses'],
#  ['seedier', 'desiree'],
#  ["logan's", "golan's", "anglo's"],
#  ['pigment', 'temping'],
#  ['quieter', 'requite'],
#  ['storied', 'editors', 'steroid', 'sortied'],
#  ['broth', 'throb'],
#  ["goiter's", "goitre's"],
#  ['seals', 'sales'],
#  ['happiest', 'epitaphs'],
#  ['gnarliest', 'triangles', 'integrals'],
#  ['liars', 'rails', 'lairs', 'liras'],
#  ['racing', 'arcing', 'caring'],
#  ['purples', 'suppler'],
#  ['deltas', 'lasted', 'slated', 'salted', 'staled'],
#  ['directest', 'trisected'],
#  ['hocked', 'choked'],
#  ['shot', 'host'],
#  ['stamen', 'mantes'],
#  ['knits', 'stink'],
#  ['research', 'searcher'],
#  ["marta's", "marat's", "tamra's"],
#  ['lattes', 'latest'],
#  ['crinkles', 'clinkers'],
#  ["dion's", "odin's", "dino's"],
#  ['looting', 'tooling'],
#  ['naive', 'nivea', 'evian'],
#  ['scrapes', 'parsecs'],
#  ['warehouses', 'housewares'],
#  ['lelia', 'leila', 'allie'],
#  ['nebula', 'unable'],
#  ['waders', 'seward'],
#  ['turbines', 'tribunes'],
#  ['decants', 'scanted', 'descant'],
#  ['trio', 'riot', 'tiro'],
#  ['psalters', 'plasters', 'staplers'],
#  ['spars', 'rasps'],
#  ["lift's", "flit's"],
#  ['magnetos', 'megatons', 'montages'],
#  ['gris', 'rigs'],
#  ['ribbon', 'robbin'],
#  ['regina', 'regain'],
#  ["thor's", "roth's"],
#  ['curbs', 'scrub'],
#  ['inklings', 'slinking'],
#  ["leap's", "peal's", "plea's", "pale's"],
#  ['eviler', 'revile', 'relive'],
#  ["louse's", "seoul's"],
#  ['futon', 'fount'],
#  ["tacitness's", "cattiness's"],
#  ['wallows', 'swallow'],
#  ['nips', 'pins', 'spin', 'snip'],
#  ["file's", "life's", "leif's"],
#  ['gab', 'bag'],
#  ['rogues', 'grouse', 'rouges'],
#  ['turnover', 'overturn'],
#  ["acre's", "care's", "race's"],
#  ['malinger', 'germinal'],
#  ['spinal', 'plains'],
#  ['rereads', 'readers'],
#  ['nudity', 'untidy'],
#  ['lesa', 'leas', 'elsa', 'ales', 'seal', 'sale'],
#  ['yelped', 'deeply'],
#  ["dusty's", "study's"],
#  ['mortise', 'moister'],
#  ['lathe', 'letha'],
#  ['tiara', 'atria', 'atari'],
#  ["throe's", "other's"],
#  ['toaster', 'rotates', 'rosetta'],
#  ['eastern', 'nearest', 'earnest'],
#  ['builder', 'rebuild'],
#  ['nave', 'vane', 'neva', 'evan'],
#  ['outer', 'route'],
#  ['signally', 'sallying'],
#  ['latrine', 'reliant', 'latiner', 'retinal'],
#  ['towel', 'owlet'],
#  ['sere', 'erse', 'seer'],
#  ['blogging', 'boggling'],
#  ['sunlit', 'insult'],
#  ['vietcong', 'coveting'],
#  ['dopiest', 'deposit', 'posited', 'topside'],
#  ["startup's", "upstart's"],
#  ['zoned', 'dozen'],
#  ['cerulean', 'laurence'],
#  ["handel's", "handle's"],
#  ['loosing', 'soloing'],
#  ["narmada's", "ramadan's"],
#  ['fires', 'fries'],
#  ["aileen's", "elaine's"],
#  ['castillo', 'callisto'],
#  ['rooming', 'mooring'],
#  ['grouper', 'regroup'],
#  ["love's", "vole's"],
#  ['served', 'versed'],
#  ['albs', 'labs', 'slab', 'blasé'],
#  ['replicas', 'calipers'],
#  ['solve', 'loves', 'voles'],
#  ["calvary's", "cavalry's"],
#  ['rebroadcast', 'broadcaster'],
#  ['pesters', 'presets'],
#  ['midges', 'smidge'],
#  ['métier', 'merit', 'timer', 'remit', 'miter'],
#  ['veto', 'vote'],
#  ['burs', 'rubs'],
#  ['loafing', 'foaling'],
#  ["sign's", "sing's"],
#  ['rises', 'sires'],
#  ['decimated', 'medicated'],
#  ["median's", "medina's", "damien's", "maiden's"],
#  ['baste', 'beast', 'beats', 'betas', 'abets', 'bates'],
#  ['tension', 'intones'],
#  ['robe', 'ebro', 'boer', 'bore'],
#  ['bear', 'reba', 'bare'],
#  ["cortes's", "corset's", "sector's", "escort's"],
#  ['suture', 'uterus'],
#  ['beseech', 'beeches'],
#  ["tang's", "gnat's"],
#  ["rank's", "króna's", "nark's"],
#  ["rumba's", "burma's"],
#  ['shlep', 'helps'],
#  ['wiggler', 'wriggle'],
#  ['boring', 'robing'],
#  ["voile's", "olive's"],
#  ['sherd', 'herds', 'shred'],
#  ["cadre's", "cedar's"],
#  ['tin', 'nit'],
#  ['recounting', 'countering'],
#  ['plainest', 'panelist'],
#  ["porter's", "report's"],
#  ['cups', 'cusp'],
#  ["crocus's", "succor's"],
#  ['expect', 'except'],
#  ['printer', 'reprint'],
#  ['snipe', 'pines', 'penis', 'spine'],
#  ['remington', 'mentoring'],
#  ['angers', 'sanger', 'ranges'],
#  ['carlyle', 'clearly'],
#  ['editing', 'dieting', 'ignited'],
#  ['insets', 'steins'],
#  ['leaden', 'leaned'],
#  ['alinement', 'lineament'],
#  ['shlocky', 'shylock'],
#  ['reprise', 'respire'],
#  ['halsey', 'ashley'],
#  ['grandee', 'enraged', 'derange', 'angered', 'grenade'],
#  ["bed's", "deb's"],
#  ['chum', 'much'],
#  ['intrude', 'untried'],
#  ['stove', 'votes'],
#  ['coiled', 'docile'],
#  ["mood's", "odom's", "doom's"],
#  ['wreathes', 'weathers'],
#  ['stunned', 'dunnest'],
#  ['chiefest', 'fetiches'],
#  ["dorothea's", "theodora's"],
#  ["ocean's", "canoe's"],
#  ['just', 'juts'],
#  ["berger's", "gerber's"],
#  ["earp's", "rape's", "pear's"],
#  ['pyre', 'prey'],
#  ['dustin', 'nudist'],
#  ["scot's", "cost's"],
#  ['teacher', 'cheater', 'hectare'],
#  ['permissions', 'impressions'],
#  ['topsides', 'deposits'],
#  ['discoverers', 'rediscovers'],
#  ['collared', 'carolled'],
#  ['disport', 'tripods'],
#  ['gentian', 'anteing', 'antigen'],
#  ['guiana', 'iguana'],
#  ['kitsch', 'shtick'],
#  ['rename', 'meaner'],
#  ['beasts', 'basest', 'bastes'],
#  ['manors', 'romans', 'ransom'],
#  ['heal', 'hale', 'leah'],
#  ['into', 'toni'],
#  ["veda's", "dave's"],
#  ["garden's", "danger's", "gander's"],
#  ['sidebars', 'seabirds'],
#  ['lube', 'blue'],
#  ['diverse', 'derives', 'revised'],
#  ['riel', 'rile', 'lire'],
#  ["arneb's", "abner's"],
#  ["roeg's", "ogre's", "gore's"],
#  ["polo's", "loop's", "pool's"],
#  ['vigor', 'virgo'],
#  ['teresa', 'teaser', 'easter', 'eaters'],
#  ['alcove', 'coeval'],
#  ["aol's", "ola's", "lao's"],
#  ['initiated', 'dietitian'],
#  ['teazle', 'teazel'],
#  ['gainsays', 'assaying'],
#  ['brush', 'shrub'],
#  ['asleep', 'please', 'elapse'],
#  ['chatters', 'ratchets'],
#  ['tokes', 'stoke'],
#  ["cupola's", "copula's"],
#  ["mel's", "mêlée's", "elm's"],
#  ["boer's", "ebro's", "bore's", "robe's"],
#  ["skater's", "streak's"],
#  ['ipecacs', 'icecaps'],
#  ['escorts', 'corsets', 'sectors'],
#  ['mashing', 'shaming'],
#  ["herod's", "horde's"],
#  ['diners', 'rinsed', 'snider'],
#  ['laconic', 'conical'],
#  ["purse's", "super's"],
#  ['impersonated', 'predominates'],
#  ['idles', 'sidle', 'slide', 'delis'],
#  ['sergio', 'orgies'],
#  ['tolyatti', 'totality'],
#  ["suez's", "zeus's"],
#  ['greed', 'edger'],
#  ["pursuer's", "usurper's"],
#  ['deeding', 'deigned'],
#  ['acton', 'canto'],
#  ['inured', 'ruined'],
#  ['outside', 'tedious'],
#  ["domination's", "admonition's"],
#  ['demount', 'mounted'],
#  ["oyster's", "storey's"],
#  ['schnabel', 'blanches'],
#  ["silt's", "list's", "slit's"],
#  ['altitudes', 'latitudes'],
#  ['orb', 'rob'],
#  ['ashen', 'shane'],
#  ['balder', 'blared'],
#  ['insures', 'sunrise'],
#  ['ron', 'nor'],
#  ['deferment', 'fermented'],
#  ["ruination's", "urination's"],
#  ["grade's", "edgar's"],
#  ['shade', 'ashed', 'hades', 'heads'],
#  ['yacht', 'cathy'],
#  ['bagel', 'gable'],
#  ['nelda', 'laden', 'alden'],
#  ['breaths', 'bathers'],
#  ['sexist', 'exists'],
#  ['wolves', 'vowels'],
#  ['trading', 'darting'],
#  ["gamine's", "enigma's"],
#  ['idea', 'aide'],
#  ['doings', 'dosing'],
#  ['tensing', 'nesting'],
#  ['deli', 'idle', 'lied'],
#  ['those', 'ethos'],
#  ['lao', 'aol', 'ola'],
#  ['aspirate', 'parasite'],
#  ['inverts', 'striven'],
#  ['jean', 'jane'],
#  ['plug', 'gulp'],
#  ['glinting', 'tingling'],
#  ['racier', 'carrie'],
#  ['deranging', 'gardening'],
#  ['roes', 'eros', 'rose', 'sore', 'ores'],
#  ['serpens', 'spenser'],
#  ["tipper's", "trippe's"],
#  ['defrost', 'frosted'],
#  ['angering', 'enraging'],
#  ["cleaner's", "carlene's"],
#  ['dianne', 'dannie', 'nadine'],
#  ['salivated', 'validates'],
#  ['owns', 'sown', 'snow'],
#  ['emirate', 'meatier'],
#  ['driblets', 'bristled'],
#  ['lela', 'ella'],
#  ['dearth', 'thread', 'hatred'],
#  ['greet', 'egret'],
#  ['soldier', 'solider', 'deloris'],
#  ['god', 'dog'],
#  ['relief', 'refile', 'liefer'],
#  ['lorgnettes', 'longstreet'],
#  ['bucked', 'dubcek'],
#  ['mating', 'taming'],
#  ['stance', 'ascent', 'enacts'],
#  ['electives', 'selective'],
#  ['smears', 'ramses'],
#  ['laurel', 'allure'],
#  ['mate', 'tame', 'team', 'meat'],
#  ['assuage', 'sausage'],
#  ['friend', 'finder'],
#  ["mason's", "osman's"],
#  ['cradle', 'calder'],
#  ['fates', 'feats', 'feast'],
#  ['ruthless', 'hustlers'],
#  ['sunburned', 'unburdens'],
#  ['sieved', 'devise'],
#  ['rectifiable', 'certifiable'],
#  ['einstein', 'nineties'],
#  ['crater', 'tracer', 'carter'],
#  ['chicks', 'schick'],
#  ["christian's", "christina's"],
#  ['mads', 'dams'],
#  ["dowry's", "rowdy's"],
#  ["chianti's", "chaitin's"],
#  ['vast', 'vats'],
#  ['discoverer', 'rediscover'],
#  ['rationalize', 'realization'],
#  ['estimates', 'steamiest'],
#  ['umps', 'sump'],
#  ["catt's", "tact's"],
#  ['crete', 'erect'],
#  ['mes', 'ems'],
#  ['gores', 'gorse', 'ogres'],
#  ['salinger', 'slangier'],
#  ["specter's", "respect's", "scepter's"],
#  ['body', 'boyd'],
#  ['anchor', 'charon'],
#  ['mien', 'mine'],
#  ["large's", "lager's", "alger's", "glare's", "elgar's"],
#  ['parboil', 'bipolar'],
#  ['hags', 'gash', 'shag'],
#  ['bermuda', 'rumbaed'],
#  ['incognito', 'cognition'],
#  ['rate', 'tare', 'tear'],
#  ['aligned', 'dealing', 'leading'],
#  ['army', 'myra', 'mary'],
#  ['patching', 'nightcap'],
#  ['break', 'brake', 'baker'],
#  ['inward', 'darwin'],
#  ['sprouting', 'posturing'],
#  ["nate's", "ante's", "etna's"],
#  ['rocks', 'corks'],
#  ['locust', 'clouts'],
#  ['stinted', 'dentist'],
#  ["alb's", "lab's"],
#  ["wasp's", "swap's"],
#  ['rowdy', 'wordy', 'dowry'],
#  ['scares', 'caress'],
#  ['dolly', 'lloyd'],
#  ['drainage', 'gardenia'],
#  ['twit', 'witt'],
#  ['fronde', 'fonder'],
#  ['claps', 'scalp', 'clasp'],
#  ['goals', 'lagos'],
#  ['upsets', 'setups'],
#  ['bastion', 'obtains'],
#  ['biogen', 'boeing'],
#  ['conserved', 'conversed'],
#  ['bristle', 'blister'],
#  ['aging', 'nigga'],
#  ['wean', 'wane', 'anew'],
#  ['dreamiest', 'diameters'],
#  ['hatreds', 'dearths', 'trashed', 'threads', 'hardest'],
#  ['misdeed', 'demised'],
#  ["graze's", "gazer's"],
#  ['debris', 'brides'],
#  ["deposit's", "topside's"],
#  ['wrest', 'strew'],
#  ['calks', 'lacks', 'slack'],
#  ["pone's", "open's", "peon's"],
#  ['weirder', 'rewired'],
#  ['martens', 'smarten'],
#  ['rounded', 'redound'],
#  ['amphitheaters', 'amphitheatres'],
#  ['boats', 'boast'],
#  ['gnats', 'angst', 'tangs'],
#  ['weir', 'wire'],
#  ["teazle's", "teazel's"],
#  ['alissa', 'assail'],
#  ["jason's", "jonas's", "sonja's"],
#  ["saltiness's", "stainless's"],
#  ['oort', 'root'],
#  ['spores', 'posers'],
#  ['reorging', 'rogering'],
#  ["alnilam's", "manilla's"],
#  ["grist's", "grits's"],
#  ['himself', 'flemish'],
#  ['burden', 'burned'],
#  ['inters', 'insert'],
#  ['publisher', 'republish'],
#  ['things', 'nights'],
#  ['admen', 'named', 'amend', 'medan'],
#  ['aline', 'alien'],
#  ["haydn's", "handy's"],
#  ['reel', 'leer'],
#  ["lariat's", "altair's"],
#  ['pediatrics', 'patricides'],
#  ['creators', 'reactors'],
#  ['togas', 'goats'],
#  ['ex', 'xe'],
#  ['talon', 'tonal', 'alton'],
#  ['tardier', 'tarried'],
#  ['rambles', 'marbles'],
#  ['tonnes', 'sonnet', 'tenons'],
#  ['remarks', 'markers'],
#  ['skipper', 'kippers'],
#  ['erasing', 'regains', 'searing'],
#  ['crusty', 'curtsy'],
#  ['mordant', 'dormant'],
#  ['nope', 'open', 'peon', 'pone'],
#  ['ten', 'net'],
#  ['macerated', 'demarcate'],
#  ['abut', 'tuba', 'batu', 'tabu'],
#  ['muggles', 'smuggle'],
#  ['blasted', 'stabled', 'baldest'],
#  ['lagniappe', 'appealing'],
#  ['among', 'mango'],
#  ["gunshot's", "shotgun's"],
#  ['decadents', 'descanted'],
#  ['nuts', 'stun', 'tuns'],
#  ["bos'n's", "bo's'ns"],
#  ["cain's", "inca's"],
#  ['cackled', 'clacked'],
#  ['joni', 'join'],
#  ["castor's", "costar's", "castro's"],
#  ["girdle's", "glider's"],
#  ['geared', 'agreed'],
#  ["ingres's", "signer's", "singer's"],
#  ['lethe', 'ethel'],
#  ["romans's", "ransom's"],
#  ['marker', 'kramer', 'remark'],
#  ['crudest', 'crusted'],
#  ['ameba', 'abeam'],
#  ['splendid', 'spindled'],
#  ["tsar's", "star's"],
#  ["iran's", "nair's", "rain's"],
#  ['bounder', 'rebound'],
#  ["monroe's", "moreno's"],
#  ['sates', 'asset', 'easts', 'seats', 'tessa'],
#  ['enemy', 'yemen'],
#  ['crisped', 'précised'],
#  ['trashes', 'rashest'],
#  ['reassure', 'erasures'],
#  ['boards', 'broads'],
#  ['mars', 'arms', 'rams'],
#  ['timon', 'minot'],
#  ['sheila', 'elisha', 'shelia'],
#  ["brief's", "fiber's"],
#  ['oder', 'rode', 'doer', 'redo'],
#  ["enervation's", "veneration's"],
#  ['dallies', 'sallied'],
#  ['boarded', 'roadbed'],
#  ["potash's", "pathos's"],
#  ['leif', 'lief', 'life', 'file'],
#  ['dilatory', 'adroitly', 'idolatry'],
#  ["mar's", "ram's", "arm's"],
#  ['foci', 'coif'],
#  ['indigents', 'destining'],
#  ['sumac', 'camus'],
#  ["loaner's", "lenora's", "elnora's", "lorena's", "elanor's"],
#  ['sombrely', 'somberly'],
#  ["wear's", "ware's"],
#  ['seabeds', 'debases'],
#  ['thousand', 'handouts'],
#  ["flirtation's", "filtration's"],
#  ['moist', 'omits'],
#  ['tens', 'sent', 'nets', 'nest'],
#  ['isle', 'leis', 'lies'],
#  ['noelle', 'leonel'],
#  ['tern', 'rent'],
#  ["link's", "kiln's"],
#  ['pesos', 'posse', 'poses'],
#  ['bogeyman', 'moneybag'],
#  ['dingo', 'doing'],
#  ['names', 'manes', 'means', 'manse', 'mensa'],
#  ["gallery's", "allergy's"],
#  ['steiner', 'entries'],
#  ['dust', 'stud'],
#  ['peals', 'pales', 'pleas', 'leaps', 'lapse', 'sepal'],
#  ['resting', 'stinger'],
#  ['ashanti', 'tanisha'],
#  ['carve', 'crave'],
#  ['sleep', 'peels'],
#  ['alums', 'mauls'],
#  ['caused', 'sauced'],
#  ['arline', 'linear'],
#  ['bleated', 'belated'],
#  ['cutters', 'curtest'],
#  ['page', 'gape'],
#  ['marciano', 'macaroni'],
#  ['rascals', 'scalars'],
#  ["girt's", "trig's", "grit's"],
#  ['roisters', 'resistor', 'sorriest'],
#  ['dam', 'mad', 'amd'],
#  ['germanic', 'creaming'],
#  ['uterine', 'reunite', 'retinue'],
#  ["felt's", "left's"],
#  ['delude', 'eluded', 'dueled'],
#  ['gums', 'mugs', 'smug'],
#  ['prefects', 'perfects'],
#  ['snooped', 'spooned'],
#  ["angel's", "galen's", "angle's"],
#  ["broth's", "throb's"],
#  ['frees', 'reefs'],
#  ['relays', 'layers', 'slayer'],
#  ["darlene's", "leander's"],
#  ['bed', 'deb'],
#  ['denatures', 'sauntered'],
#  ["girth's", "right's"],
#  ["hines's", "shine's"],
#  ['miracles', 'reclaims'],
#  ['timbres', 'timbers'],
#  ['eons', 'nose', 'enos', 'ones', 'noes'],
#  ['torso', 'roost', 'roots'],
#  ['touché', 'touch'],
#  ['titans', 'taints'],
#  ["trestle's", "settler's"],
#  ['ant', 'tan', 'nat'],
#  ["tar's", "rat's", "art's"],
#  ['chisel', 'chiles'],
#  ['randi', 'darin', 'nadir', 'indra', 'drain'],
#  ['swig', 'wigs'],
#  ['kiwi', 'wiki'],
#  ["radon's", "drano's", "norad's", "ronda's"],
#  ['creditor', 'director'],
#  ['angels', 'gleans', 'angles'],
#  ['buttering', 'rebutting'],
#  ["silent's", "listen's", "tinsel's"],
#  ["mace's", "acme's"],
#  ['sower', 'worse', 'swore'],
#  ['easy', 'ayes', 'yeas'],
#  ['settlers', 'trestles'],
#  ['cartier', 'erratic'],
#  ['opens', 'epson', 'pones', 'peons'],
#  ['socrates', 'coasters', 'coarsest'],
#  ["pôrto's", "port's"],
#  ['raked', 'drake'],
#  ['eery', 'eyre'],
#  ['forrest', 'forster'],
#  ['today', 'toady'],
#  ['tilde', 'tiled'],
#  ['swing', 'wings'],
#  ['saints', 'stains'],
#  ["fine's", "enif's"],
#  ["reserve's", "reverse's"],
#  ['sinecure', 'insecure'],
#  ['lea', 'ale'],
#  ['staling', 'salting', 'lasting', 'slating'],
#  ['ajar', 'raja'],
#  ['mantissa', 'satanism'],
#  ['esters', 'steers', 'serest', 'resets'],
#  ["lee's", "eel's"],
#  ['soils', 'solis', 'silos'],
#  ['sims', 'isms', 'miss'],
#  ['deter', 'treed'],
#  ["ides's", "side's"],
#  ["caterer's", "terrace's"],
#  ['naomi', 'amino'],
#  ['lenin', 'linen'],
#  ["maori's", "mario's", "moira's"],
#  ['eroding', 'negroid', 'ignored', 'redoing'],
#  ['silts', 'slits', 'lists'],
#  ["sepoy's", "poesy's"],
#  ["signing's", "singing's"],
#  ["snipe's", "penis's", "spine's"],
#  ["étude's", "duet's"],
#  ['ranger', 'garner'],
#  ["ramble's", "marble's"],
#  ["snob's", "bos'ns"],
#  ['rolando', 'orlando'],
#  ['impugns', 'spuming'],
#  ['comte', 'comet'],
#  ['sterna', 'astern'],
#  ["path's", "ptah's"],
#  ['mister', 'merits', 'timers', 'miters', 'remits', 'métiers'],
#  ['similes', 'missile'],
#  ["oneal's", "leona's"],
#  ['disinters', 'dirtiness'],
#  ['years', 'ayers'],
#  ['ginsu', 'using', 'suing'],
#  ['tortilla', 'littoral'],
#  ['observes', 'obverses'],
#  ['teens', 'tense'],
#  ['baidu', 'dubai'],
#  ['splatter', 'platters', 'prattles'],
#  ['ashe', 'shea'],
#  ['aws', 'saw', 'was'],
#  ["recital's", "article's"],
#  ['grabs', 'garbs', 'brags'],
#  ["salem's", "selma's"],
#  ['sluts', 'lusts'],
#  ["elbert's", "treble's"],
#  ["sahel's", "leash's", "shale's"],
#  ['goat', 'toga'],
#  ['defeats', 'feasted', 'deafest'],
#  ['hosed', 'shoed'],
#  ['diabetes', 'beadiest'],
#  ['crabs', 'carbs'],
#  ['milfs', 'films'],
#  ['inclosure', 'cornelius'],
#  ['tons', 'snot'],
#  ['tail', 'alit'],
#  ['fest', 'fêtes'],
#  ['rca', 'arc', 'car'],
#  ['allover', 'overall'],
#  ['recipes', 'precise', 'pierces'],
#  ['molders', 'smolder'],
#  ["ashe's", "shea's"],
#  ["mail's", "mali's", "lima's"],
#  ['boredom', 'bedroom'],
#  ["nod's", "don's"],
#  ["annam's", "manna's"],
#  ['owlish', 'lowish'],
#  ['hate', 'thea', 'heat'],
#  ["ferry's", "fryer's"],
#  ["town's", "wont's"],
#  ['lodging', 'golding'],
#  ['onset', 'stone', 'seton', 'notes', 'tones'],
#  ['ramada', 'armada'],
#  ['gust', 'guts', 'tugs'],
#  ['coil', 'clio', 'loci'],
#  ['scum', 'cums'],
#  ['leaner', 'arlene'],
#  ['nosier', 'senior'],
#  ['calumnies', 'masculine'],
#  ['demo', 'mode', 'dome'],
#  ["leak's", "lake's", "kale's"],
#  ["kusch's", "shuck's"],
#  ['serried', 'dreiser'],
#  ['stein', 'stine', 'nites', 'inset', 'tines'],
#  ['steaming', 'mangiest'],
#  ['logs', 'slog'],
#  ["cane's", "acne's"],
#  ['haney', 'hyena'],
#  ['poling', 'loping'],
#  ['brighten', 'berthing'],
#  ['layout', 'outlay'],
#  ['tidiness', 'insisted'],
#  ['punks', 'spunk'],
#  ['dowel', 'lowed'],
#  ['study', 'dusty'],
#  ['olive', 'voile'],
#  ['earths', 'haters', 'hearst', 'hearts'],
#  ['forester', 'reforest'],
#  ["sue's", "use's"],
#  ["anchor's", "charon's"],
#  ['rustle', 'luster', 'ulster', 'result', 'lustre'],
#  ['sperm', 'perms'],
#  ['lively', 'evilly', 'vilely'],
#  ['basis', 'bassi'],
#  ['magenta', 'magnate'],
#  ['deserts', 'dessert'],
#  ['pistol', 'pilots', 'spoilt'],
#  ['lookouts', 'outlooks'],
#  ['mit', 'tim'],
#  ['garret', 'garter', 'grater'],
#  ['tearing', 'ingrate', 'tangier', 'granite'],
#  ['hints', 'thins'],
#  ['carp', 'crap'],
#  ['dab', 'bad'],
#  ['lapels', 'aspell'],
#  ['drawing', 'warding'],
#  ['lips', 'slip', 'lisp'],
#  ['arrested', 'retreads', 'serrated'],
#  ['susie', 'issue'],
#  ['deer', 'reed'],
#  ["sifter's", "strife's"],
#  ['tansy', 'nasty'],
#  ["gail's", "gila's"],
#  ['niggaz', 'gazing'],
#  ['berra', 'barer'],
#  ['endings', 'sending'],
#  ["lump's", "plum's"],
#  ['genres', 'greens'],
#  ['shriek', 'hikers', 'shrike'],
#  ['taster', 'stater', 'treats'],
#  ['maribel', 'balmier'],
#  ['sunlight', 'hustling'],
#  ['marc', 'cram'],
#  ['ortega', 'garote', 'tagore'],
#  ['hustle', 'sleuth'],
#  ['rigged', 'digger'],
#  ["wiggler's", "wriggle's"],
#  ["lie's", "lei's", "eli's"],
#  ['waning', 'awning'],
#  ['ramadan', 'narmada'],
#  ['héloise', 'helios'],
#  ["tarpon's", "patron's"],
#  ['nair', 'rain', 'iran'],
#  ['filed', 'flied', 'fidel', 'field'],
#  ['dampest', 'stamped'],
#  ['owes', 'woes'],
#  ['palmists', 'psalmist'],
#  ['misled', 'smiled'],
#  ["infarction's", "infraction's"],
#  ['swaddle', 'dawdles', 'waddles'],
#  ['wither', 'writhe', 'whiter'],
#  ['trinkets', 'knitters'],
#  ['nectarines', 'transience'],
#  ['retrains', 'strainer', 'terrains', 'trainers', 'restrain'],
#  ["crane's", "nacre's"],
#  ['deifying', 'edifying'],
#  ['newer', 'renew'],
#  ["drainage's", "gardenia's"],
#  ['holster', 'hostler'],
#  ['swede', 'sewed', 'weeds'],
#  ['causally', 'casually'],
#  ['scope', 'copse', 'pecos', 'copes'],
#  ['austerer', 'treasure'],
#  ['stewing', 'twinges'],
#  ['okra', 'karo'],
#  ['decal', 'laced'],
#  ['rankle', 'lanker'],
#  ['dwayne', 'yawned'],
#  ['teak', 'kate', 'take'],
#  ['decimation', 'medication'],
#  ['baird', 'braid', 'rabid'],
#  ["saffron's", "sarnoff's"],
#  ['seller', 'resell'],
#  ['sages', 'gases'],
#  ['serenading', 'grenadines'],
#  ['derail', 'relaid', 'railed'],
#  ['gneiss', 'singes'],
#  ['coat', 'taco', 'cato'],
#  ['debit', 'bidet'],
#  ['romps', 'proms'],
#  ["jeffery's", "jeffrey's"],
#  ['remus', 'serum'],
#  ['dora', 'road'],
#  ['duster', 'rudest', 'rusted'],
#  ['inelegant', 'eglantine'],
#  ['caster', 'carets', 'caters', 'traces', 'recast', 'crates', 'reacts'],
#  ['stint', 'tints'],
#  ["vector's", "covert's"],
#  ['enervates', 'venerates'],
#  ['wader', 'dewar'],
#  ['serving', 'versing'],
#  ['bustle', 'subtle', 'sublet', 'bluest'],
#  ['spawn', 'pawns'],
#  ["weal's", "wale's"],
#  ["soil's", "lois's", "silo's"],
#  ['rices', 'cries'],
#  ['designer', 'resigned', 'redesign'],
#  ['atomizers', 'amortizes'],
#  ['disuse', 'issued'],
#  ["rattan's", "tartan's"],
#  ['riders', 'driers'],
#  ["cray's", "cary's"],
#  ['manila', 'animal', 'malian'],
#  ['specie', 'pieces'],
#  ['roister', 'rioters'],
#  ['acorns', 'carson'],
#  ['echos', 'chose'],
#  ['darren', 'errand'],
#  ['scream', 'creams'],
#  ["éclair's", "clair's"],
#  ['catechisms', 'schematics'],
#  ['minnesota', 'nominates'],
#  ['clarion', 'conrail'],
#  ["lynne's", "lenny's"],
#  ['stumble', 'tumbles'],
#  ["avila's", "avail's"],
#  ['satiny', 'sanity'],
#  ["harte's", "heart's", "earth's", "hater's"],
#  ['gentiles', 'steeling', 'sleeting'],
#  ['cleric', 'circle'],
#  ["vial's", "vila's"],
#  ["denier's", "nereid's"],
#  ['spouts', 'tossup'],
#  ['stygian', 'staying'],
#  ['angel', 'galen', 'glean', 'angle'],
#  ['longitudes', 'ungodliest'],
#  ['wordier', 'rowdier', 'worried'],
#  ["angela's", "galena's"],
#  ['sigh', 'gish'],
#  ['solver', 'lovers'],
#  ['pailsful', 'pailfuls'],
#  ["pinto's", "piton's", "point's"],
#  ['shark', 'harks'],
#  ['nerved', 'vender', 'denver'],
#  ['decimates', 'medicates'],
#  ['warder', 'reward', 'drawer', 'warred', 'redraw'],
#  ['dusters', 'trussed'],
#  ['stricter', 'restrict', 'critters'],
#  ['halting', 'lathing'],
#  ["dread's", "adder's"],
#  ['lilting', 'tilling'],
#  ['rub', 'bur'],
#  ['drollest', 'strolled'],
#  ['algenib', 'belgian', 'bengali'],
#  ['speer', 'spree', 'peers'],
#  ['flue', 'fuel'],
#  ["toaster's", "rosetta's"],
#  ['peel', 'pele'],
#  ['polemic', 'compile'],
#  ['pintos', 'points', 'pitons', 'piston'],
#  ['swaps', 'wasps'],
#  ['petitioners', 'repetitions'],
#  ['fiscal', 'califs'],
#  ['taper', 'prate', 'apter', 'petra'],
#  ['mitered', 'merited', 'demerit'],
#  ["faker's", "freak's"],
#  ['slyest', 'styles'],
#  ['valeria', 'valarie'],
#  ['pyres', 'preys', 'ypres'],
#  ["putin's", "input's"],
#  ["teacher's", "hectare's", "cheater's"],
#  ['pillages', 'spillage'],
#  ["wrestle's", "swelter's"],
#  ['usurpers', 'pursuers'],
#  ['strait', 'artist', 'traits'],
#  ['mustered', 'demurest'],
#  ['tender', 'rented'],
#  ["roomer's", "romero's"],
#  ['reside', 'eiders', 'desire'],
#  ['pisces', 'spices'],
#  ['undressing', 'undersigns'],
#  ['loots', 'tools', 'stool'],
#  ['erections', 'secretion'],
#  ['eliseo', 'eloise'],
#  ['romanies', 'moraines'],
#  ['reheat', 'heater'],
#  ['recasting', 'caterings'],
#  ['blogged', 'boggled'],
#  ["fart's", "frat's", "raft's"],
#  ['resales', 'sealers'],
#  ['acrider', 'carried'],
#  ['schiller', 'chillers'],
#  ['staph', 'paths'],
#  ["resident's", "dniester's"],
#  ['boner', 'borne'],
#  ["puree's", "rupee's"],
#  ["baud's", "daub's"],
#  ["phrase's", "sharpe's", "sherpa's", "seraph's"],
#  ['heartiness', 'earthiness'],
#  ['waddle', 'dawdle'],
#  ['tome', 'moet', 'mote'],
#  ['paged', 'gaped'],
#  ['raps', 'rasp', 'pars', 'spar'],
#  ['meant', 'manet'],
#  ['descent', 'scented'],
#  ['fats', 'fast'],
#  ['resinous', 'neurosis'],
#  ["steak's", "skate's", "keats's", "stake's"],
#  ["chum's", "much's"],
#  ['duffer', 'ruffed'],
#  ["drive's", "diver's", "verdi's"],
#  ['decanted', 'decadent'],
#  ['recondition', 'conditioner'],
#  ['tropism', 'imports'],
#  ['medalist', 'misdealt'],
#  ['brailles', 'liberals', 'ballsier'],
#  ["caroline's", "cornelia's"],
#  ["outtake's", "takeout's"],
#  ["paris's", "parsi's"],
#  ['deserve', 'severed'],
#  ['reversing', 'reserving'],
#  ["ni's", "in's"],
#  ['care', 'acre', 'race'],
#  ['salve', 'vales', 'slave'],
#  ['clair', 'éclair'],
#  ["cutlery's", "cruelty's"],
#  ['below', 'elbow', 'bowel'],
#  ['whereat', 'wreathe', 'weather'],
#  ['faster', 'strafe'],
#  ['avon', 'nova'],
#  ['schubert', 'butchers'],
#  ["danial's", "dalian's"],
#  ['pedals', 'pleads', 'lapsed'],
#  ["batman's", "bantam's"],
#  ['pastels', 'staples'],
#  ['soirées', 'osiers'],
#  ["plate's", "patel's", "petal's", "pleat's"],
#  ['tickers', 'rickets', 'sticker'],
#  ['deliver', 'relived', 'reviled'],
#  ['airy', 'iyar'],
#  ['with', 'whit'],
#  ["mir's", "rim's"],
#  ['adobe', 'abode'],
#  ['decrees', 'recedes'],
#  ['raven', 'verna'],
#  ['niggles', 'leggins', 'negligs'],
#  ['earthy', 'hearty'],
#  ['bowls', 'blows'],
#  ["tester's", "street's", "setter's"],
#  ['keri', 'erik'],
#  ["lubber's", "rubble's"],
#  ["magnate's", "magenta's"],
#  ["feta's", "fate's", "feat's"],
#  ["leta's", "teal's", "tale's"],
#  ["actuator's", "autocrat's"],
#  ['wands', 'dawns'],
#  ["oct's", "cot's"],
#  ['harkened', 'hankered'],
#  ['catered', 'reacted', 'created'],
#  ["miss's", "sims's"],
#  ['dues', 'used', 'sued', 'duse'],
#  ['toed', 'dote'],
#  ['algorithms', 'logarithms'],
#  ['wingspan', 'spawning'],
#  ['premisses', 'impresses'],
#  ["asset's", "tessa's"],
#  ['ethan', 'neath'],
#  ['alger', 'lager', 'elgar', 'glare', 'regal', 'large'],
#  ["achoo's", "ochoa's"],
#  ["tab's", "bat's"],
#  ['tabbies', 'babiest'],
#  ['tocsins', 'consist'],
#  ['torts', 'trots'],
#  ['acres', 'races', 'cesar', 'scare', 'cares'],
#  ['drier', 'rider', 'direr'],
#  ['retinues', 'reunites'],
#  ["hades's", "shade's"],
#  ['stagnation', 'antagonist'],
#  ['pares', 'spare', 'rapes', 'reaps', 'pears', 'spear', 'parse'],
#  ['tenants', 'tannest'],
#  ['balk', 'kalb'],
#  ['topic', 'optic'],
#  ['reworks', 'workers'],
#  ['cargoes', 'corsage'],
#  ["comrade's", "mercado's"],
#  ["raul's", "ural's"],
#  ["pathogen's", "heptagon's"],
#  ['direct', 'credit'],
#  ['martial', 'marital'],
#  ['looped', 'pooled', 'poodle'],
#  ['decorations', 'coordinates'],
#  ['sage', 'ages', 'sega'],
#  ['sheri', 'hires', 'shire', 'heirs'],
#  ["caring's", "racing's"],
#  ['hewn', 'when'],
#  ['damion', 'domain'],
#  ['nameless', 'lameness', 'salesmen', 'maleness'],
#  ['irksome', 'smokier'],
#  ['catalogues', 'coagulates'],
#  ['teals', 'steal', 'tesla', 'stael', 'stale', 'slate', 'least', 'tales'],
#  ["minuet's", "minute's"],
#  ["molar's", "moral's"],
#  ["spar's", "rasp's"],
#  ['attunes', 'tetanus'],
#  ['melton', 'molten'],
#  ['amgen', 'mange', 'manège', 'megan'],
#  ["melisa's", "ismael's"],
#  ["auction's", "caution's"],
#  ["density's", "destiny's"],
#  ['striking', 'skirting'],
#  ['mildness', 'mindless'],
#  ['chastens', 'stanches', 'snatches'],
#  ['broadside', 'sideboard'],
#  ['samara', 'asmara'],
#  ['lames', 'selma', 'meals', 'males', 'salem'],
#  ["erna's", "rena's"],
#  ['sharp', 'harps'],
#  ["allie's", "leila's", "lelia's"],
#  ['dave', 'veda'],
#  ['clematises', 'timescales'],
#  ['sprinter', 'reprints', 'printers'],
#  ['casserole', 'escaroles'],
#  ['altering', 'relating', 'alerting', 'integral', 'triangle'],
#  ['replace', 'percale'],
#  ['shrikes', 'shrieks'],
#  ['mediums', 'dummies'],
#  ['cyrano', 'crayon'],
#  ['skis', 'kiss'],
#  ['stinker', 'kristen', 'kirsten', 'tinkers'],
#  ["ruth's", "hurt's"],
#  ['reckon', 'rockne'],
#  ['tale', 'teal', 'leta', 'late'],
#  ['untruer', 'nurture'],
#  ["thing's", "night's"],
#  ['halts', 'shalt', 'laths'],
#  ['pronto', 'proton'],
#  ['lydia', 'daily'],
#  ["oh's", "ho's"],
#  ['stony', 'tyson'],
#  ['varlets', 'travels'],
#  ['tarts', 'start'],
#  ['predatory', 'portrayed'],
#  ['defray', 'frayed'],
#  ['irving', 'virgin'],
#  ['bearded', 'breaded'],
#  ["romance's", "cameron's"],
#  ['mile', 'lime', 'emil'],
#  ['ginned', 'ending'],
#  ["acrostic's", "socratic's"],
#  ['dies', 'ides', 'side'],
#  ['sting', 'tings'],
#  ['covert', 'vector'],
#  ['hilbert', 'blither'],
#  ['futons', 'founts'],
#  ['eastman', 'smetana'],
#  ["littoral's", "tortilla's"],
#  ['lois', 'soli', 'oils', 'soil', 'silo'],
#  ['nixed', 'index'],
#  ['yates', 'yeats', 'yeast'],
#  ['slivering', 'silvering'],
#  ['pincer', 'prince'],
#  ["tangerine's", "argentine's"],
#  ['attaché', 'attach'],
#  ['raises', 'arises'],
#  ["driblet's", "dilbert's"],
#  ["salon's", "sloan's"],
#  ['shames', 'mashes'],
#  ['tars', 'tsar', 'rats', 'arts', 'star'],
#  ['midterm', 'trimmed'],
#  ["yemen's", "enemy's"],
#  ["toga's", "goat's"],
#  ["recount's", "counter's"],
#  ['tactile', 'lattice'],
#  ['girding', 'ridging'],
#  ["browse's", "bowers's"],
#  ['pesky', 'skype'],
#  ['peeking', 'keeping'],
#  ['ochre', 'chore', 'roche', 'ocher'],
#  ["dolly's", "lloyd's"],
#  ['mussier', 'surmise'],
#  ["doorbell's", "bordello's"],
#  ...]

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
